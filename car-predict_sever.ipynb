# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
import pickle

#load model
# filename = 'carprice_model.pha'
filename = 'x_model.sav'
loaded_model = pickle.load(open(filename, 'rb'))
    
def predictCar(brand,province,colour,mile,old):
#     brand = 'Toyota,Corolla'
#     province = 'กรุงเทพและปริมณฑล'
#     colour = 'ขาว'
#     mile = 147500.0
#     old = 8
    def find_basic_data_car(brand,province,colour,mile,old):
    
        def findMax(v):
        #     v = 'engine'
            max_name = ''
            max_n = 0
            for i in df[v].unique():
                if df[df[v]==i].shape[0] > max_n:
                    max_n = df[df[v]==i].shape[0]
                    max_name = i
            return max_name

        df = pd.read_csv("car_clean.csv",header=0)
        df = df[df.brand == brand]
        df = df[df.old == 8]

        engine = findMax('engine')
        gear = findMax('gear')
        seat = findMax('seat')
        fuel = findMax('fuel')

        return engine,gear,seat,fuel




    engine,gear,seat,fuel = find_basic_data_car(brand,province,colour,mile,old)
    post = 0

    df = pd.read_csv("car_clean.csv",header=0)

    x = df.drop(['price'],axis=1)
    y = df['price']
    y = np.ravel(y);

    # t = ['Toyota,Corolla',147500.0,8,1986,'A',5,'กรุงเทพและปริมณฑล','ขาว','Petrol',1] #5567
    t = [brand,mile,old,engine,gear,seat,province,colour,fuel,post]
    h = ['brand','mile','old','engine','gear','seat','province','colour','fuel','post']
    df2 = pd.DataFrame([t], columns=h)
    x2 = x.append(df2, ignore_index=True)



    scaler = MinMaxScaler(feature_range=(0,1))

    x2["mile"]=scaler.fit_transform(x2[["mile"]])
    x2["old"]=scaler.fit_transform(x2[["old"]])
    x2["engine"]=scaler.fit_transform(x2[["engine"]])
    x2["post"]=scaler.fit_transform(x2[["post"]])

    x2 = pd.get_dummies(x2, dummy_na = False, columns=['brand', 'gear', 'seat','province','colour','fuel'])

    y_pred2 = loaded_model.predict([x2.loc[x2.shape[0]-1]])

    return y_pred2[0]
# Out:
# /home/phawit/anaconda3/lib/python3.8/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeRegressor from version 0.22.2.post1 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /home/phawit/anaconda3/lib/python3.8/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator RandomForestRegressor from version 0.22.2.post1 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
from firebase import Firebase

config = {
  "apiKey": "AIzaSyBGv_05cA2Qm1QEuKUZ4U-hFCiyxc1e_8A",
  "authDomain": "car-price-bbaa2.firebaseapp.com",
  "databaseURL": "https://car-price-bbaa2.firebaseio.com",
  "storageBucket": "car-price-bbaa2.appspot.com",
  "serviceAccount": "car-price-bbaa2-firebase-adminsdk-hk1k5-7dd02ad457.json"
    
}

firebase = Firebase(config)
db = firebase.database()


def set_events():
    all_events = db.child("events").get()
    e = []
    for i in all_events.each():
        e.append(i.key())
    return set(e)

result = set_events()
while True:
    add = set_events() - result
    if len(add) > 0:
        print('add :', add)
        for i in add:
            x = db.child("events/"+str(i)).get()
            brand = x.val()['brand']
            year = x.val()['year']
            mile = x.val()['mile']
            colour = x.val()['colour']
            province = x.val()['province']

            old = 2020-int(year)

            print(type(brand))
            print(year)
            print(mile)
            print(type(colour))
            print(province)

            p = predictCar(brand,province,colour,mile,old)
            print('price {i} :::::::',p)
            db.child("events").child(str(i)+'/y').set(p)

        result = set_events()
# Out:
# add : {'1605544683767'}
# <class 'str'>
# 1995
# 156132
# <class 'str'>
# ภาคกลาง
# price {i} ::::::: 310083.6
# add : {'1605544939339'}
# <class 'str'>
# 2013
# 300000
# <class 'str'>
# ภาคอีสาน
# price {i} ::::::: 376310.0
# add : {'1605545019602'}
# <class 'str'>
# 2013
# 300000
# <class 'str'>
# ภาคอีสาน
# price {i} ::::::: 267719.8
# add : {'1605545023572'}
# <class 'str'>
# 2013
# 300000
# <class 'str'>
# กรุงเทพและปริมณฑล
# price {i} ::::::: 263188.6666666666
# add : {'1605545028835'}
# <class 'str'>
# 2013
# 300000
# <class 'str'>
# ภาคเหนือ
# price {i} ::::::: 279970.0
# add : {'1605545042481'}
# <class 'str'>
# 2013
# 300000
# <class 'str'>
# ภาคเหนือ
# price {i} ::::::: 377480.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-fb73cd2422f8> in <module>
#      23 result = set_events()
#      24 while True:
# ---> 25     add = set_events() - result
#      26     if len(add) > 0:
#      27         print('add :', add)
#
# <ipython-input-2-fb73cd2422f8> in set_events()
#      15
#      16 def set_events():
# ---> 17     all_events = db.child("events").get()
#      18     e = []
#      19     for i in all_events.each():
#
# ~/anaconda3/lib/python3.8/site-packages/firebase/__init__.py in get(self, token, json_kwargs)
#     280         request_ref = self.build_request_url(token)
#     281         headers = self.build_headers(token)
# --> 282         request_object = self.requests.get(request_ref, headers=headers)
#     283         raise_detailed_error(request_object)
#     284         request_dict = request_object.json(**json_kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     541
#     542         kwargs.setdefault('allow_redirects', True)
# --> 543         return self.request('GET', url, **kwargs)
#     544
#     545     def options(self, url, **kwargs):
#
# ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~/anaconda3/lib/python3.8/http/client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv("car_clean.csv",header=0)
df.brand.unique()
# Out:
# array(['Toyota,Yaris', 'Nissan,Teana', 'Honda,Civic', 'Toyota,Vios',
#        'Toyota,Hilux', 'Mazda,2', 'Honda,CR-V', 'Honda,Jazz', 'BMW,320d',
#        'Mercedes-Benz,E200', 'Mini,Cooper', 'BMW,530e',
#        'Mercedes-Benz,C180', 'Honda,City', 'Mercedes-Benz,E220',
#        'Mercedes-Benz,E250', 'Toyota,Landcruiser', 'Toyota,Camry',
#        'Toyota,Hiace', 'BMW,520d', 'Honda,Accord', 'Mercedes-Benz,E300',
#        'Honda,HR-V', 'Toyota,Corolla', 'Toyota,C-HR', 'BMW,X1',
#        'Isuzu,D-Max', 'MG,MG5', 'Toyota,Alphard', 'Toyota,Vellfire',
#        'MG,GS', 'Toyota,Innova', 'Mazda,CX-5', 'Ford,Ranger', 'Volvo,S80',
#        'Honda,Mobilio', 'Mazda,3', 'Mitsubishi,Triton',
#        'Chevrolet,Trailblazer', 'Mitsubishi,Pajero', 'Nissan,Big',
#        'Nissan,Juke', 'Lexus,RX350', 'Nissan,Frontier', 'Audi,A6',
#        'Porsche,Cayenne', 'Toyota,Fortuner', 'Toyota,Esquire',
#        'Mercedes-Benz,C350', 'Suzuki,Swift', 'BMW,X3', 'Nissan,Serena',
#        'BMW,318i', 'Mercedes-Benz,E350', 'Ford,Everest',
#        'Mercedes-Benz,CLA250', 'Audi,Q8', 'Mitsubishi,Mirage',
#        'Mercedes-Benz,GLA200', 'BMW,525d', 'BMW,M6', 'Nissan,Almera',
#        'Bentley,Continental', 'Isuzu,MU-X', 'BMW,X5', 'Suzuki,Ciaz',
#        'Nissan,Note', 'Subaru,XV', 'Volvo,XC60', 'Nissan,March',
#        'Mercedes-Benz,C300', 'BMW,523i', 'Toyota,Commuter', 'Kia,Grand',
#        'Chevrolet,Cruze', 'Mercedes-Benz,230E', 'Chevrolet,Colorado',
#        'Mitsubishi,Xpander', 'Volvo,850', 'BMW,330e', 'BMW,323i',
#        'Mercedes-Benz,S280', 'Nissan,X-Trail', 'Suzuki,Carry',
#        'Ford,Fiesta', 'Mercedes-Benz,C250', 'Mercedes-Benz,A170',
#        'Mercedes-Benz,C63', 'Toyota,Corona', 'Mercedes-Benz,E280',
#        'Ford,Mustang', 'Subaru,Forester', 'Volvo,S70', 'Nissan,Sunny',
#        'Toyota,Avanza', 'Isuzu,MU-7', 'Mitsubishi,Space', 'BMW,320Ci',
#        'Hyundai,Sonata', 'Mercedes-Benz,GLA250', 'BMW,528i',
#        'Volkswagen,Caravelle', 'BMW,320i', 'Mercedes-Benz,GLE250',
#        'Mercedes-Benz,SLK200', 'Lamborghini,Gallardo', 'BMW,730Li',
#        'Mercedes-Benz,ML250', 'Volvo,V50', 'Ford,EcoSport', 'Ford,Focus',
#        'Nissan,Tiida', 'Mercedes-Benz,SLK250', 'Honda,Brio',
#        'Citroen,Xantia', 'Mitsubishi,Lancer', 'BMW,430i', 'Hyundai,H-1',
#        'Porsche,911', 'Nissan,Cefiro', 'Toyota,Sport', 'Audi,Q5',
#        'Mercedes-Benz,CLS300', 'MG,MG3', 'Mercedes-Benz,GLC250',
#        'Volvo,V60', 'Porsche,Panamera', 'Mercedes-Benz,CLS250',
#        'Mazda,BT-50', 'Toyota,Ventury', 'Honda,Freed', 'Porsche,Macan',
#        'Nissan,NP', 'BMW,Z4', 'Fiat,131S', 'Toyota,Prius', 'BMW,X2',
#        'Mercedes-Benz,E53', 'Mercedes-Benz,500SEC',
#        'Mercedes-Benz,SLC300', 'BMW,X4', 'Nissan,NV',
#        'Mercedes-Benz,E240', 'Chevrolet,Captiva', 'Ford,Territory',
#        'Chevrolet,Camaro', 'Mitsubishi,Attrage', 'Mazda,CX-3',
#        'Mercedes-Benz,C220', 'Chevrolet,Sonic', 'Isuzu,Adventure',
#        'BMW,525i', 'Porsche,Cayman', 'Mercedes-Benz,190E',
#        'Nissan,Sylphy', 'Bentley,Flying', 'Volkswagen,Golf',
#        'Mercedes-Benz,SLK55', 'Subaru,Impreza', 'Mazda,MX-5', 'Volvo,264',
#        'Nissan,350Z', 'Jaguar,XF', 'Chevrolet,Zafira', 'BMW,118i',
#        'Toyota,ALPHARD', 'Nissan,Terra', 'Jeep,Wrangler', 'Volvo,XC40',
#        'BMW,I8', 'Mercedes-Benz,300TD', 'Lexus,RX270',
#        'Mercedes-Benz,CLA200', 'Toyota,Wish', 'Mercedes-Benz,SL280',
#        'Nissan,Skyline', 'Nissan,GT-R', 'Audi,R8', 'Volvo,S60',
#        'Mercedes-Benz,C200', 'BMW,218i', 'BMW,325i', 'Lexus,RX300',
#        'Honda,BR-V', 'Citroen,Xsara', 'Mercedes-Benz,ML320', 'BMW,420d',
#        'Honda,Odyssey', 'Mitsubishi,Strada', 'Mitsubishi,ATTRAGE',
#        'MG,ZS', 'Toyota,Land', 'MG,MG6', 'Jaguar,S-Type', 'Jaguar,XJR',
#        'Subaru,Legacy', 'BMW,ActiveHybrid', 'Toyota,Estima',
#        'Toyota,Sienta', 'Volvo,XC90', 'Aston,V8', 'BMW,520i', 'Volvo,940',
#        'BMW,M3', 'Mercedes-Benz,CLK200', 'Toyota,Harrier', 'BMW,740Le',
#        'Mazda,RX-8', 'Audi,TT', 'Lexus,LS430', 'Proton,Savvy',
#        'Toyota,Celica', 'Volvo,S90', 'Volvo,V70', 'Land,Range',
#        'Ferrari,F355', 'Toyota,Crown', 'Mini,Austin',
#        'Mercedes-Benz,S300', 'Volvo,V40', 'BMW,420Ci',
#        'Mercedes-Benz,S350', 'Smart,Roadster', 'Toyota,HARRIER',
#        'Volkswagen,Passat', 'Toyota,VELLFIRE', 'Nissan,Pulsar',
#        'Porsche,Boxster', 'BMW,730Ld', 'BMW,316i', 'Ferrari,F430',
#        'BMW,M5', 'Mercedes-Benz,CLA180', 'BMW,328i', 'Lexus,NX300h',
#        'Toyota,Soarer', 'Ford,Escape', 'Chevrolet,Spin', 'BMW,630i',
#        'GMC,Yukon', 'Mercedes-Benz,SL300', 'Mercedes-Benz,A45',
#        'Volkswagen,Scirocco', 'Mercedes-Benz,GLE500',
#        'Mercedes-Benz,SL500', 'Isuzu,Cameo', 'Suzuki,APV', 'Isuzu,TFR',
#        'Toyota,VIOS', 'Mercedes-Benz,Vito', 'Suzuki,Ertiga',
#        'Honda,STEPWGN', 'Tata,Xenon', 'Mercedes-Benz,E230', 'Audi,A4',
#        'Volkswagen,New', 'Mazda,Tribute', 'BMW,i8', 'Hyundai,Grand',
#        'Hyundai,Elantra', 'Honda,ACCORD', 'Proton,Exora', 'Audi,Q3',
#        'Mercedes-Benz,S320', 'Porsche,CAYENNE', 'BMW,530i',
#        'Mercedes-Benz,S600', 'Nissan,370Z', 'Nissan,Xciter',
#        'Suzuki,Spacia', 'BMW,X6', 'Honda,N-ONE', 'Volkswagen,Touareg',
#        'Mercedes-Benz,CLS53', 'Mercedes-Benz,S500',
#        'Mercedes-Benz,SLK230', 'BMW,218Ci', 'BMW,M4', 'Audi,A7',
#        'Mercedes-Benz,CLA45', 'Honda,N-BOX', 'Porsche,928',
#        'Mercedes-Benz,CLS350', 'Jaguar,XJ6', 'Jaguar,Sovereign',
#        'Mercedes-Benz,280CE', 'Porsche,PANAMERA',
#        'Mercedes-Benz,Sprinter', 'Lexus,LS460', 'Mercedes-Benz,V250',
#        'Porsche,718', 'Toyota,YARIS', 'Lexus,ES300', 'Mercedes-Benz,A180',
#        'Kia,Picanto', 'Ferrari,California', 'Audi,TTS', 'Chevrolet,Optra',
#        'Opel,Corsa', 'Honda,Integra', 'BMW,740Li', 'BMW,330i',
#        'Mazda,Atenza', 'Nissan,Elgrand', 'Volkswagen,Transporter',
#        'Volkswagen,Beetle', 'Toyota,Supra', 'Jaguar,XJ', 'BMW,325Ci',
#        'Mercedes-Benz,C43', 'Suzuki,Celerio', 'Mercedes-Benz,GLC43',
#        'Cadillac,Escalade', 'Suzuki,SX4', 'Lexus,IS250',
#        'Mercedes-Benz,C230', 'Lexus,GS250', 'Peugeot,408', 'Lexus,RX200t',
#        'Audi,A1', 'Mercedes-Benz,A250', 'Audi,Q7', 'Mercedes-Benz,A200',
#        'Isuzu,Dragon', 'Toyota,Kluger', 'Fiat,500', 'Ferrari,F456',
#        'Mercedes-Benz,220S', 'Citroen,DS', 'Ford,Laser', 'Chevrolet,Aveo',
#        'Land,Discovery', 'Land,Defender', 'Subaru,BRZ', 'Honda,Stream',
#        'Volvo,960', 'Mercedes-Benz,500SEL', 'Jaguar,F-Pace',
#        'Mercedes-Benz,200E', 'Mercedes-Benz,Viano', 'Jeep,Cherokee',
#        'BMW,750i', 'Toyota,Tundra', 'Subaru,R2', 'Jaguar,XK8',
#        'Mazda,CX-7', 'Nissan,Urvan', 'Mercedes-Benz,450SL', 'Honda,CITY',
#        'Toyota,WISH', 'Mercedes-Benz,CLS220', 'Mercedes-Benz,300SEL',
#        'Mazda,CX-8', 'Mercedes-Benz,E63', 'BMW,116i', 'McLaren,650S',
#        'McLaren,MP4-12C', 'McLaren,570S', 'Mercedes-Benz,B200',
#        'Mercedes-Benz,GLE43', 'Toyota,86', 'Toyota,FJ', 'TR,Adventure',
#        'BMW,X7', 'Ssangyong,Stavic', 'Mazda,121', 'Mercedes-Benz,GLE350',
#        'Mercedes-Benz,GLC220', 'Alfa,156', 'Lexus,CT200h',
#        'Mercedes-Benz,220', 'Mercedes-Benz,SL350', 'Mazda,Fighter',
#        'Alfa,GTV', 'Audi,RS3', 'Suzuki,WAGON', 'Toyota,HIACE',
#        'Mercedes-Benz,ML300', 'Ferrari,458', 'Ferrari,488',
#        'Mercedes-Benz,S560', 'Ferrari,F12', 'Mercedes-Benz,SLC43',
#        'Mercedes-Benz,B180', 'Honda,JAZZ', 'Hyundai,Veloster',
#        'Toyota,COROLLA', 'Mini,COOPER', 'Honda,CR-Z', 'Audi,S5', 'BMW,M2',
#        'BMW,325d', 'Subaru,Outback', 'Kia,Carnival',
#        'Maserati,Granturismo', 'Toyota,Soluna', 'BMW,318Ci',
#        'Mercedes-Benz,E55', 'McLaren,675LT', 'Mercedes-Benz,GT',
#        'Audi,A8', 'Suzuki,Vitara', 'Nissan,Livina', 'Land,Freelander',
#        'Mercedes-Benz,Maybach', 'Mercedes-Benz,R300', 'Volvo,S40',
#        'TR,Transformer', 'Kia,K2900', 'Cadillac,Fleetwood',
#        'Suzuki,Caribian', 'Lamborghini,Huracan', 'BMW,M760Li',
#        'BMW,640Ci', 'Toyota,Altezza', 'Smart,Fortwo',
#        'Mercedes-Benz,GL350', 'BMW,730iL', 'Mercedes-Benz,GLC300',
#        'Maserati,Levante', 'Porsche,CAYMAN', 'BMW,630d', 'Peugeot,307',
#        'Daihatsu,Mira', 'Peugeot,308', 'Lexus,GS300', 'Lexus,LS500',
#        'Mercedes-Benz,CLA35', 'BMW,520', 'Hummer,H3',
#        'Lamborghini,GALLARDO', 'BMW,M850i', 'Mercedes-Benz,S400',
#        'Mercedes-Benz,300E', 'Mitsubishi,Evolution', 'BMW,735Li',
#        'Mercedes-Benz,CLK240', 'Kia,Soul', 'Mercedes-Benz,560SEL',
#        'Jeep,Grand', 'Mitsubishi,Galant', 'Citroen,C4', 'Alfa,GT',
#        'Mercedes-Benz,380SEC', 'Fiat,Ducato', 'Peugeot,807', 'Chery,QQ',
#        'Volvo,C30', 'Mercedes-Benz,G350', 'Mitsubishi,Delica',
#        'Mercedes-Benz,300D', 'Mercedes-Benz,ML280', 'Honda,Airwave',
#        'Isuzu,Trooper', 'Maserati,Quattroporte', 'Toyota,AVANZA',
#        'Mercedes-Benz,SLR', 'Lamborghini,Aventador', 'Mercedes-Benz,A160',
#        'Mercedes-Benz,C36', 'Mercedes-Benz,CLS63', 'Jeep,Renegade',
#        'Lexus,IS', 'Audi,RS5', 'Infiniti,G', 'Rolls-Royce,Phantom',
#        'Toyota,Mark', 'Mercedes-Benz,CL500', 'Honda,S2000', 'Kia,K2500',
#        'TR,Grand', 'Volkswagen,Amarok', 'BMW,740iL',
#        'Mercedes-Benz,GLE300', 'Ford,GT', 'Chrysler,300C', 'Aston,Rapide',
#        'Toyota,Rav4', 'Ferrari,F599', 'Toyota,MR2', 'Volkswagen,Sharan',
#        'Nissan,200SX', 'Isuzu,Grand', 'Audi,A5', 'Mini,One',
#        'Mercedes-Benz,BRABUS', 'Volvo,144', 'Mazda,CX-9', 'Peugeot,3008',
#        'Honda,Prelude', 'Mercedes-Benz,R350', 'Mitsuoka,Galue',
#        'Toyota,SOLUNA', 'Lexus,LS460L', 'Ferrari,F360', 'Seat,Alhambra',
#        'Nissan,Sentra', 'Daihatsu,Atrai', 'Maxus,V80', 'Nissan,Cedric',
#        'BMW,730i', 'Mitsubishi,FTO', 'BMW,220i', 'Jaguar,XE',
#        'Daihatsu,Opti', 'Holden,Calais', 'Chevrolet,Corvette',
#        'Daihatsu,Hijet', 'Toyota,LN', 'Joylong,A6', 'Proton,Neo',
#        'Mercedes-Benz,GLB200', 'Toyota,Sparky', 'Alfa,Spider',
#        'McLaren,720S', 'Volkswagen,Polo', 'Suzuki,Hustler', 'Nissan,NX',
#        'Toyota,Granvia', 'Lamborghini,Murcielago', 'Chevrolet,Astro',
#        'Austin,A90', 'Audi,Q2', 'Nissan,280ZX', 'Kia,Carens',
#        'Nissan,Murano', 'Peugeot,206', 'Isuzu,Faster', 'Tata,Super',
#        'Peugeot,407', 'Citroen,BX', 'Jaguar,Daimler', 'Saab,900',
#        'Lexus,LS600hL', 'Hyundai,H-100', 'Toyota,bB', 'Lotus,Exige',
#        'Aston,DB11', 'Kia,Rio', 'Bentley,Turbo', 'Lexus,LS400',
#        'Proton,Preve', 'Hummer,H2', 'Nissan,Silvia', 'Toyota,Voxy',
#        'Rolls-Royce,Silver', 'Chevrolet,Lumina', 'Kia,Jumbo', 'Isuzu,ELF',
#        'Mercedes-Benz,250', 'Mercedes-Benz,CLK320', 'Lexus,IS300h',
#        'Toyota,VANGUARD', 'Proton,Persona', 'Nissan,Cube', 'Rover,Mini',
#        'Suzuki,Jimny', 'Honda,CR-X', 'Kia,Sportage', 'Honda,Today',
#        'Isuzu,Vega', 'Toyota,iQ', 'Peugeot,607', 'Mitsubishi,Canter',
#        'Mazda,Familia', 'Peugeot,RCZ', 'Honda,Legend', 'Audi,A3',
#        'Mercedes-Benz,SLS', 'Mercedes-Benz,CLK230', 'Toyota,TownAce',
#        'BMW,635d', 'Mercedes-Benz,220D', 'Mercedes-Benz,SL320',
#        'Ferrari,308', 'Lotus,Esprit', 'Ferrari,GTC4', 'Subaru,Levorg',
#        'Mercedes-Benz,G300', 'Peugeot,605', 'Mercedes-Benz,300CE',
#        'Porsche,BOXSTER', 'Saab,9000', 'Mercedes-Benz,SL600',
#        'Fiat,Punto', 'Citroen,C5'], dtype=object)
